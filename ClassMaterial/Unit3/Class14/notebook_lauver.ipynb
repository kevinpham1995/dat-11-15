# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor, plot_tree
import numpy as np

# %%
df = pd.read_csv(r'/Users/lauverm/dat-11-15/Homework/Unit2/data/housing.csv')
tree = DecisionTreeRegressor(max_depth = 4)

# %%
X = df.drop('PRICE', axis = 1)
y = df['PRICE']

tree.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = (18, 12))
plot_tree(tree, fontsize = 12, feature_names = X.columns, filled = True);

# %%
#ste 1: start off with a naive prediction for your dataset
guess = y.mean()

# %%
guess
# Out:
# 22.532806324110698

# %%
gradient = y - guess #in regular regression, this error column is the gradient

# %%
tree
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
tree.fit(X, gradient)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
tree.predict(X) # predicts the amount of error based on the previous round of boosting
# Out:
# array([  4.8944664 ,  -0.90306273,  10.21597416,  10.21597416,
#         10.21597416,  -0.90306273,  -0.90306273,  -2.51197299,
#         -2.51197299,  -2.51197299,  -2.51197299,  -0.90306273,
#         -2.51197299,  -0.90306273,  -0.90306273,  -0.90306273,
#         -0.90306273,  -6.29384529,  -0.90306273,  -0.90306273,
#         -6.29384529,  -0.90306273,  -6.29384529,  -6.29384529,
#         -6.29384529,  -6.29384529,  -6.29384529,  -6.29384529,
#         -0.90306273,   4.8944664 ,  -6.29384529,  -0.90306273,
#         -6.29384529,  -6.29384529,  -6.29384529,  -0.90306273,
#         -0.90306273,  -0.90306273,  -0.90306273,   4.8944664 ,
#         10.21597416,   4.8944664 ,  -0.90306273,  -0.90306273,
#         -0.90306273,  -0.90306273,  -0.90306273,  -2.51197299,
#         -2.51197299,  -2.51197299,  -0.90306273,  -0.90306273,
#         -0.90306273,  -0.90306273,  -2.51197299,  10.21597416,
#         -0.90306273,   4.8944664 ,  -0.90306273,  -0.90306273,
# ...

# %%
guess += tree.predict(X)

# %%
guess # this concludes the first round of boosting
# Out:
# array([27.42727273, 21.62974359, 32.74878049, 32.74878049, 32.74878049,
#        21.62974359, 21.62974359, 20.02083333, 20.02083333, 20.02083333,
#        20.02083333, 21.62974359, 20.02083333, 21.62974359, 21.62974359,
#        21.62974359, 21.62974359, 16.23896104, 21.62974359, 21.62974359,
#        16.23896104, 21.62974359, 16.23896104, 16.23896104, 16.23896104,
#        16.23896104, 16.23896104, 16.23896104, 21.62974359, 27.42727273,
#        16.23896104, 21.62974359, 16.23896104, 16.23896104, 16.23896104,
#        21.62974359, 21.62974359, 21.62974359, 21.62974359, 27.42727273,
#        32.74878049, 27.42727273, 21.62974359, 21.62974359, 21.62974359,
#        21.62974359, 21.62974359, 20.02083333, 20.02083333, 20.02083333,
#        21.62974359, 21.62974359, 21.62974359, 21.62974359, 20.02083333,
#        32.74878049, 21.62974359, 27.42727273, 21.62974359, 21.62974359,
#        21.62974359, 20.02083333, 21.62974359, 27.42727273, 32.74878049,
# ...

# %%
y - guess
# Out:
# 0     -3.427273
# 1     -0.029744
# 2      1.951220
# 3      0.651220
# 4      3.451220
#          ...
# 501   -5.027273
# 502   -1.029744
# 503   -8.848780
# 504   -5.427273
# 505   -9.729744
# Name: PRICE, Length: 506, dtype: float64

# %%
gradient = y-guess

# %%
tree.fit(X, gradient)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
guess += tree.predict(X)

# %%
guess
# Out:
# array([26.63939202, 20.84186289, 31.96089979, 34.19185936, 34.19185936,
#        25.51446953, 20.84186289, 20.56864878, 18.08926959, 20.56864878,
#        20.56864878, 20.84186289, 20.56864878, 20.84186289, 20.84186289,
#        20.84186289, 25.47427859, 16.78677649, 20.84186289, 20.84186289,
#        16.78677649, 20.84186289, 16.78677649, 16.78677649, 16.78677649,
#        16.78677649, 16.78677649, 16.78677649, 20.84186289, 26.63939202,
#        16.78677649, 20.84186289, 14.3073973 , 16.78677649, 16.78677649,
#        20.84186289, 20.84186289, 20.84186289, 25.47427859, 29.16366301,
#        34.48517077, 29.16366301, 23.36613388, 23.36613388, 20.84186289,
#        20.84186289, 20.84186289, 20.56864878, 18.08926959, 20.56864878,
#        20.84186289, 20.84186289, 22.78530331, 22.78530331, 20.56864878,
#        33.90434021, 20.84186289, 26.63939202, 20.64434595, 20.84186289,
#        20.84186289, 19.23295263, 20.84186289, 26.63939202, 34.19185936,
# ...

# %%
gradient = y - guess

# %%
tree.fit(X, gradient)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
guess += tree.predict(X)

# %%
guess[:5]
# Out:
# array([26.59189641, 22.15935565, 31.91340417, 34.14436374, 34.14436374])

# %%
y[:5]
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: PRICE, dtype: float64

# %%
learning_rate = 0.1 #way to scale how much you update your model after each round of boosting - can range to .3 or .5. But smaller the better to help you not overshoot your predictions

# %%
gradient = y-guess

# %%
tree.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
guess += tree.predict(X)*learning_rate

# %%
guess
# Out:
# array([29.33462368, 24.32233001, 35.18828222, 37.41924179, 37.41924179,
#        28.99493665, 21.31879398, 23.88822488, 18.40530966, 20.88468885,
#        23.88822488, 21.31879398, 20.88468885, 21.44461207, 21.44461207,
#        21.44461207, 24.13041764, 16.85044741, 21.44461207, 21.44461207,
#        14.79535576, 21.44461207, 14.79535576, 16.85044741, 16.85044741,
#        16.85044741, 16.85044741, 16.85044741, 21.44461207, 25.76680247,
#        14.79535576, 19.38952042, 12.31597657, 14.79535576, 14.79535576,
#        23.17268664, 23.17268664, 23.17268664, 27.80510234, 31.85889467,
#        37.71255321, 31.85889467, 26.846601  , 26.846601  , 24.32233001,
#        21.31879398, 21.31879398, 20.88468885, 18.40530966, 20.88468885,
#        21.31879398, 24.32233001, 26.26577044, 23.26223441, 21.01050694,
#        37.13172265, 24.32233001, 29.33462368, 24.12481307, 21.31879398,
#        21.31879398, 19.5489927 , 24.32233001, 29.33462368, 37.41924179,
# ...

# %%
gradient = y - guess

# %%
tree.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
guess += tree.predict(X)*learning_rate

# %%
guess
# Out:
# array([32.07735095, 26.48530437, 38.46316027, 40.69411984, 40.69411984,
#        31.15791101, 23.48176834, 25.89030821, 20.40739299, 22.88677218,
#        25.89030821, 23.48176834, 22.88677218, 23.60758643, 23.60758643,
#        23.60758643, 26.293392  , 18.47434352, 23.60758643, 23.60758643,
#        16.41925186, 23.60758643, 16.41925186, 18.47434352, 18.47434352,
#        18.47434352, 18.47434352, 18.47434352, 23.60758643, 28.50952974,
#        16.41925186, 21.55249478, 13.93987267, 16.41925186, 16.41925186,
#        25.335661  , 25.335661  , 25.335661  , 29.96807669, 34.60162194,
#        40.98743126, 34.60162194, 29.00957536, 29.00957536, 26.48530437,
#        23.48176834, 23.48176834, 22.88677218, 20.40739299, 22.88677218,
#        23.48176834, 26.48530437, 28.4287448 , 25.42520877, 23.01259027,
#        40.40660069, 26.48530437, 32.07735095, 26.28778743, 23.48176834,
#        23.48176834, 21.55107603, 26.48530437, 32.07735095, 40.69411984,
# ...

# %%
y[:5]
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: PRICE, dtype: float64

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbm = GradientBoostingRegressor()

# %%
gbm.get_params()
# Out:
# {'alpha': 0.9,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'ls',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'presort': 'auto',
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
#n_estimaters = # of boosting rounds; use validation_fraction to id where / when to stop
