# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeRegressor
import category_encoders as ce

# %%
df=pd.read_csv(r"https://raw.githubusercontent.com/sydneyproject000/dat-sample/main/iowa_mini.csv")

# %%
# fill in missing reservations
df.fillna(0)

# drop missing values from shifts
# Out:
#         Id  MSSubClass MSZoning  LotArea Neighborhood  OverallQual  \
# 0        1          60       RL     8450      CollgCr            7
# 1        2          20       RL     9600      Veenker            6
# 2        3          60       RL    11250      CollgCr            7
# 3        4          70       RL     9550      Crawfor            7
# 4        5          60       RL    14260      NoRidge            8
# ...    ...         ...      ...      ...          ...          ...
# 1455  1456          60       RL     7917      Gilbert            6
# 1456  1457          20       RL    13175       NWAmes            6
# 1457  1458          70       RL     9042      Crawfor            7
# 1458  1459          20       RL     9717        NAmes            5
# 1459  1460          20       RL     9937      Edwards            5
#
#       OverallCond  YearBuilt  GrLivArea  1stFlrSF  2ndFlrSF  GrLivArea.1  \
# 0               5       2003       1710       856       854         1710
# 1               8       1976       1262      1262         0         1262
# 2               5       2001       1786       920       866         1786
# 3               5       1915       1717       961       756         1717
# 4               5       2000       2198      1145      1053         2198
# ...           ...        ...        ...       ...       ...          ...
# 1455            5       1999       1647       953       694         1647
# 1456            6       1978       2073      2073         0         2073
# 1457            9       1941       2340      1188      1152         2340
# 1458            6       1950       1078      1078         0         1078
# 1459            6       1965       1256      1256         0         1256
#
#       FullBath  HalfBath GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 0            2         1     Attchd       2003.0          RFn           2
# 1            2         0     Attchd       1976.0          RFn           2
# 2            2         1     Attchd       2001.0          RFn           2
# 3            1         0     Detchd       1998.0          Unf           3
# 4            2         1     Attchd       2000.0          RFn           3
# ...        ...       ...        ...          ...          ...         ...
# 1455         2         1     Attchd       1999.0          RFn           2
# 1456         2         0     Attchd       1978.0          Unf           2
# 1457         2         0     Attchd       1941.0          RFn           1
# 1458         1         0     Attchd       1950.0          Unf           1
# 1459         1         1     Attchd       1965.0          Fin           1
#
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 19 columns]

# %%
df[['GrLivArea', 'Neighborhood', 'OverallQual', 'YearBuilt', '1stFlrSF']]
# Out:
#       GrLivArea Neighborhood  OverallQual  YearBuilt  1stFlrSF
# 0          1710      CollgCr            7       2003       856
# 1          1262      Veenker            6       1976      1262
# 2          1786      CollgCr            7       2001       920
# 3          1717      Crawfor            7       1915       961
# 4          2198      NoRidge            8       2000      1145
# ...         ...          ...          ...        ...       ...
# 1455       1647      Gilbert            6       1999       953
# 1456       2073       NWAmes            6       1978      2073
# 1457       2340      Crawfor            7       1941      1188
# 1458       1078        NAmes            5       1950      1078
# 1459       1256      Edwards            5       1965      1256
#
# [1460 rows x 5 columns]

# %%
X = df[['GrLivArea', 'Neighborhood', 'OverallQual','YearBuilt', '1stFlrSF']]
y = df['SalePrice']

# %%
# let's assume these were our optimized parameters
tree = DecisionTreeRegressor(max_depth = 6, max_features = 0.8, min_samples_leaf = 10)

pipe=make_pipeline(ce.TargetEncoder(), tree)

# %%
# fit the tree, and export it
pipe.fit(X, y)
# Out:
# Pipeline(steps=[('targetencoder', TargetEncoder(cols=['Neighborhood'])),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=6, max_features=0.8,
#                                        min_samples_leaf=10))])

# %%
# the pickle module allows you to export saved models
import pickle

# rb -- WRITE the file in BYTES
with open('pipe.pkl', 'wb') as export:
    # this creates an external version of the file that we can now import later on
    pickle.dump(pipe, export)

# %%
# we can now import this, and re-use it on new data:  very handy

with open('pipe.pkl', 'rb') as import_:
    # this will import the pickled object again
    pipe2 = pickle.load(import_)

# %%
# here it is
pipe2
# Out:
# Pipeline(steps=[('targetencoder', TargetEncoder(cols=['Neighborhood'])),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=6, max_features=0.8,
#                                        min_samples_leaf=10))])

# %%
# and we can use it to make new predictions
pipe2.predict(X)
# Out:
# array([182280.36526946, 164906.64      , 212251.75      , ...,
#        260705.26315789, 139691.        , 111059.52985075])

# %%
GrLivArea_= '500'
OverallQual_= '3'
Neighborhood_='Veenker'
YearBuilt_ = '1999'
FirstFlrSF_= '500'

# %%
sample = {'GrLivArea':GrLivArea_,
         'OverallQual': OverallQual_,
         'Neighborhood':Neighborhood_,
         'YearBuilt':YearBuilt_,
         '1stFlrSF': FirstFlrSF_}


sample=pd.DataFrame(sample, index = [0])

# %%
pipe2.predict(sample)[0]
# Out:
# 317524.5294117647
